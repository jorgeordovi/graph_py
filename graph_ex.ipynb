# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
x = np.linspace(1,10,100)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title('Reg Bar Graph')
plt.xlabel('X Axix')
plt.ylabel('Y axix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y, color='red', linestyle='--', linewidth=2)
plt.title('Reg Bar Graph')
plt.xlabel('X Axix')
plt.ylabel('Y axix')
plt.annotate('Max Point', xy=(np.pi/2, 1), xytext=(np.pi/2+1, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1, label='Sin', color='blue')
plt.plot(x,y2, label='Cos', color='green')
plt.title('Reg Multi-Bar Graph')
plt.xlabel('X Axix')
plt.ylabel('Y axix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fix, axs= plt.subplots(2)

axs[0].plot(x,y1, label='Sin', color='blue')
axs[0].set_title('Sin', color='green')
axs[0].legend()

axs[1].plot(x,y2, label='Cos', color='red')
axs[1].set_title('Cos', color='green')
axs[1].legend()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y3 = np.tan(x)

plt.plot(x, y1, label='Sin')
plt.plot(x, y2, label='Cos')
plt.plot(x, y3, label='Tan', linestyle='--', color='red')

plt.title('Advanced Multi-Line Graph')
plt.xlabel('X Axix')
plt.ylabel('Y axix')
plt.legend()
plt.ylim(-10, 10) # Limit the axis y to avoid extrame values in Tan
plt.grid(True)
plt.show()

# %%
fix, axs= plt.subplots(3)

axs[0].plot(x,y1, label='Sin', color='blue')
axs[0].set_title('Sin', color='blue')
axs[0].legend()

axs[1].plot(x,y2, label='Cos', color='green')
axs[1].set_title('Cos', color='green')
axs[1].legend()

axs[2].plot(x,y3, label='Ten', color='red')
axs[2].set_title('Ten', color='red')
axs[2].legend()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cat = ['A', 'B', 'C', 'D', 'E']
val = [5, 7, 3, 8, 6]

# %%
plt.bar(cat, val, color='skyblue')
plt.title('Graph Bar Verticals')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
plt.barh(cat, val, color='skyblue')
plt.title('Graph Bar Horizontals')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
val2 = [2, 4, 6, 1, 3]

bar_width  = 0.35

plt.bar(cat, val, label='Values 1')
plt.bar(cat, val2, color='salmon', label='Values 2')

plt.title('Graph Bar Aplified')
plt.legend()
plt.show()

# %%
plt.bar(cat, val, label='Values 1', color='blue', edgecolor='white')
plt.bar(cat, val2, bottom=val, color='orange', edgecolor='white', label='Values 2', hatch='//')

plt.title('Advanced Graph Bar Aplified')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
